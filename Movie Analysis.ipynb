# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("n_movies.csv")

# %%
df.head()
# Out:
#                     title         year certificate duration  \
# 0               Cobra Kai     (2018– )       TV-14   30 min
# 1               The Crown     (2016– )       TV-MA   58 min
# 2        Better Call Saul  (2015–2022)       TV-MA   46 min
# 3           Devil in Ohio       (2022)       TV-MA  356 min
# 4  Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
#
#                                          description  \
# 0  Decades after their 1984 All Valley Karate Tou...
# 1  Follows the political rivalries and romance of...
# 2  The trials and tribulations of criminal lawyer...
# 3  When a psychiatrist shelters a mysterious cult...
# 4  A Street Kid trying to survive in a technology...
#
# ...

# %%
df.shape
# Out:
# (9957, 9)

# %%
df.columns
# Out:
# Index(['title', 'year', 'certificate', 'duration', 'genre', 'rating',
#        'description', 'stars', 'votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9957 entries, 0 to 9956
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        9957 non-null   object
#  1   year         9430 non-null   object
#  2   certificate  6504 non-null   object
#  3   duration     7921 non-null   object
#  4   genre        9884 non-null   object
#  5   rating       8784 non-null   float64
#  6   description  9957 non-null   object
#  7   stars        9957 non-null   object
#  8   votes        8784 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 700.2+ KB

# %%
df.isnull().sum()
# Out:
# title             0
# year            527
# certificate    3453
# duration       2036
# genre            73
# rating         1173
# description       0
# stars             0
# votes          1173
# dtype: int64

# %%
df.loc[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [title, year, certificate, duration, genre, rating, description, stars, votes]
# Index: []

# %%
df['votes'] = df['votes'].str.replace(',', '')

# %%
df['votes'] = pd.to_numeric(df['votes'], errors='coerce').astype('Int64')

# %%
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
original_df = df.copy()

# %%
df['year'] = df['year'].astype(str).str.extract(r'(\d{4})')[0]
df['year'] = pd.to_numeric(df['year'], errors='coerce').astype('Int64')

# %%
df.head(10)
# Out:
#                     title  year certificate duration  \
# 0               Cobra Kai  2018       TV-14   30 min
# 1               The Crown  2016       TV-MA   58 min
# 2        Better Call Saul  2015       TV-MA   46 min
# 3           Devil in Ohio  2022       TV-MA  356 min
# 4  Cyberpunk: Edgerunners  2022       TV-MA   24 min
# 5             The Sandman  2022       TV-MA   45 min
# 6          Rick and Morty  2013       TV-MA   23 min
# 7            Breaking Bad  2008       TV-MA   49 min
# 8          The Imperfects  2022       TV-MA   45 min
# 9                  Blonde  2022       NC-17  166 min
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
# 5        Drama, Fantasy, Horror     7.8
# 6  Animation, Adventure, Comedy     9.2
# 7        Crime, Drama, Thriller     9.5
# ...

# %%
df['year'].value_counts().sort_index()
# Out:
# year
# 1932      2
# 1933      1
# 1934      1
# 1935      1
# 1938      1
#        ...
# 2021    896
# 2022    781
# 2023     40
# 2024      6
# 2025      1
# Name: count, Length: 86, dtype: Int64

# %%
df['duration'] = df['duration'].str.replace('min', '')

# %%
df['duration'] = pd.to_numeric(df['duration'], errors='coerce').astype('Int64')

# %%
df.head(10)
# Out:
#                     title  year certificate  duration  \
# 0               Cobra Kai  2018       TV-14        30
# 1               The Crown  2016       TV-MA        58
# 2        Better Call Saul  2015       TV-MA        46
# 3           Devil in Ohio  2022       TV-MA       356
# 4  Cyberpunk: Edgerunners  2022       TV-MA        24
# 5             The Sandman  2022       TV-MA        45
# 6          Rick and Morty  2013       TV-MA        23
# 7            Breaking Bad  2008       TV-MA        49
# 8          The Imperfects  2022       TV-MA        45
# 9                  Blonde  2022       NC-17       166
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
# 5        Drama, Fantasy, Horror     7.8
# 6  Animation, Adventure, Comedy     9.2
# ...

# %%
df = df.dropna(subset=['rating', 'votes'])

# %%
df.isnull().sum()
# Out:
# title             0
# year              0
# certificate    2403
# duration       1104
# genre            12
# rating            0
# description       0
# stars             0
# votes             0
# dtype: int64

# %%
df = df.dropna(subset=['genre'])

# %%
df['certificate'] = df['certificate'].fillna('Unknown')

# %%
df['duration'] = df['duration'].fillna(df['duration'].median())

# %%
df.isnull().sum()
# Out:
# title          0
# year           0
# certificate    0
# duration       0
# genre          0
# rating         0
# description    0
# stars          0
# votes          0
# dtype: int64

# %%
df.head()
# Out:
#                     title  year certificate  duration  \
# 0               Cobra Kai  2018       TV-14        30
# 1               The Crown  2016       TV-MA        58
# 2        Better Call Saul  2015       TV-MA        46
# 3           Devil in Ohio  2022       TV-MA       356
# 4  Cyberpunk: Edgerunners  2022       TV-MA        24
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
#
#                                          description  \
# 0  Decades after their 1984 All Valley Karate Tou...
# 1  Follows the political rivalries and romance of...
# 2  The trials and tribulations of criminal lawyer...
# 3  When a psychiatrist shelters a mysterious cult...
# 4  A Street Kid trying to survive in a technology...
#
#                                                stars   votes
# ...

# %%
df.boxplot(column='votes')
plt.show()

# %%
df.boxplot(column='rating')
plt.show()

# %%
df.describe()
# Out:
#               year   duration       rating         votes
# count       8772.0     8772.0  8772.000000        8772.0
# mean   2015.564409  73.900821     6.763953  19549.778044
# std       8.632112  47.118078     1.214926  87635.373863
# min         1932.0        1.0     1.700000           5.0
# 25%         2015.0       45.0     6.100000         287.0
# 50%         2018.0       69.0     6.900000        1190.5
# 75%         2020.0       95.0     7.600000       5431.25
# max         2022.0      990.0     9.900000     1844075.0

# %%
df['genre'].unique()
# Out:
# array(['Action, Comedy, Drama', 'Biography, Drama, History',
#        'Crime, Drama', 'Drama, Horror, Mystery',
#        'Animation, Action, Adventure', 'Drama, Fantasy, Horror',
#        'Animation, Adventure, Comedy', 'Crime, Drama, Thriller',
#        'Action, Adventure, Drama', 'Biography, Drama, Mystery',
#        'Action, Crime, Drama', 'Drama, Horror, Thriller',
#        'Crime, Drama, Mystery', 'Comedy', 'Thriller',
#        'Drama, Romance, Sport', 'Drama, History, Horror',
#        'Drama, Romance', 'Drama, Horror, Sci-Fi',
#        'Action, Biography, Crime', 'Comedy, Romance', 'Comedy, Drama',
#        'Comedy, Drama, Romance', 'Drama, Mystery, Thriller',
#        'Action, Thriller', 'Crime, Drama, Fantasy',
#        'Action, Adventure, Comedy', 'Action, Drama, History', 'Drama',
#        'Drama, Mystery, Sci-Fi', 'Comedy, Crime',
#        'Action, Drama, Mystery', 'Drama, Fantasy, Romance',
#        'Action, Comedy, Fantasy', 'Animation, Comedy',
# ...

# %%
df['genre'].value_counts()
# Out:
# genre
# Comedy                          771
# Animation, Action, Adventure    514
# Drama                           481
# Documentary                     461
# Comedy, Drama                   274
#                                ...
# Comedy, Animation                 1
# Family, Sci-Fi, Thriller          1
# Short, Action, Adventure          1
# Short, Comedy, Crime              1
# Musical, Thriller                 1
# Name: count, Length: 546, dtype: int64

# %%
df.boxplot(column='duration')
plt.show()

# %%
df[df['duration'] > 300].shape
# Out:
# (57, 9)

# %%
df[df['duration'] > 300][['title','duration']].head(20)
# Out:
#                                           title  duration
# 3                                 Devil in Ohio       356
# 30                                       Echoes       326
# 89   Dahmer - Monster: The Jeffrey Dahmer Story       534
# 143                  The Haunting of Hill House       572
# 155                               Midnight Mass       450
# 227                                        Maid       545
# 262                   The Haunting of Bly Manor       494
# 298                                     Godless       452
# 311                                Unbelievable       385
# 367                                The Stranger       363
# 464                                 The Serpent       458
# 468           Gilmore Girls: A Year in the Life       370
# 499                                  Stay Close       375
# 568                Spartacus: Gods of the Arena       331
# 634                              The Last Dance       491
# ...

# %%
df[df['duration'] > 600].shape
# Out:
# (3, 9)

# %%
movies_df = df[df['duration'] <= 600]

# %%
series_df = df[df['duration'] > 600]

# %%
series_df
# Out:
#                     title  year certificate  duration  \
# 943       The Vietnam War  2017       TV-MA       990
# 989         The Staircase  2004       TV-MA       629
# 2116  The Time in Between  2013     Unknown       853
#
#                           genre  rating  \
# 943   Documentary, History, War     9.1
# 989   Documentary, Crime, Drama     7.8
# 2116  Adventure, Drama, History     8.3
#
#                                             description  \
# 943   A comprehensive history of the United States' ...
# 989   The high-profile murder trial of American nove...
# 2116  The life of Sira, a dressmaker consumed by the...
#
#                                                   stars  votes
# 943   ['Peter Coyote, ', 'Huy Duc, ', 'James Willban...  24632
# 989   ['Michael Peterson, ', 'David Rudolf, ', 'Ron ...  24588
# 2116  ['Adriana Ugarte, ', 'Mari Carmen Sánchez, ', ...   4258

# %%
df.to_csv("cleaned_movies.csv", index=False)
